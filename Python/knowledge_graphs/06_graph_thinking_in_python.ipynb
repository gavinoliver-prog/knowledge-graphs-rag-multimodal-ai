# %% [markdown]
# # Notebook 6 — Graph Thinking in Python
# Goal: Understand what graphs are and how to represent biological relationships using simple Python structures.

# %% [markdown]
# ## Section 1 — Nodes and Edges

# %%
nodes = ["TP53", "KRAS", "MAPK pathway"]
edges = [("TP53", "MAPK pathway"), ("KRAS", "MAPK pathway")]

print(nodes)
print(edges)

# %% [markdown]
# ### Exercises
# 1. Add another gene node.
# 2. Add another edge connecting a gene to a pathway.

# %% [markdown]
# ## Section 2 — Directed Relationships

# %%
drug_target_edges = [
    ("Trametinib", "MEK1"),
    ("Cetuximab", "EGFR")
]

drug_target_edges

# %% [markdown]
# ### Exercises
# 3. Add two additional drug–target relationships.

# %% [markdown]
# ## Section 3 — Graph Representation with Dictionaries

# %%
graph = {
    "TP53": ["Cell cycle", "Apoptosis"],
    "KRAS": ["MAPK pathway"],
    "BRAF": ["MAPK pathway"]
}

graph

# %% [markdown]
# ### Exercises
# 4. Print neighbors of KRAS.
# 5. Add EGFR with a pathway.

# %% [markdown]
# ## Section 4 — Traversing Neighbors

# %%
graph["KRAS"]

# %% [markdown]
# ### Exercises
# 6. Print neighbors of TP53.
# 7. Count number of neighbors per gene.

# %% [markdown]
# ## Section 5 — Reverse Lookup

# %%
target = "MAPK pathway"

genes = [gene for gene, pathways in graph.items() if target in pathways]

genes

# %% [markdown]
# ### Exercises
# 8. Find genes linked to 'Cell cycle'.
# 9. Find genes linked to 'Apoptosis'.

# %% [markdown]
# ## Section 6 — Node Attributes

# %%
node_attributes = {
    "TP53": {"type": "gene", "disease": "cancer"},
    "KRAS": {"type": "gene", "disease": "cancer"},
    "MAPK pathway": {"type": "pathway"}
}

node_attributes["TP53"]

# %% [markdown]
# ### Exercises
# 10. Add attributes for a drug node.
# 11. Print the type of KRAS.

# %% [markdown]
# ## Section 7 — Edge Attributes

# %%
edges = {
    ("Trametinib", "MEK1"): {"relationship": "inhibits"},
    ("Cetuximab", "EGFR"): {"relationship": "targets"}
}

edges

# %% [markdown]
# ### Exercises
# 12. Add a new edge attribute.
# 13. Print relationship for an edge.

# %% [markdown]
# ## Section 8 — Tiny Bio Knowledge Graph

# %%
patients = {
    "P1": ["KRAS"],
    "P2": ["TP53"]
}

patients

# %% [markdown]
# ### Exercises
# 14. Add another patient.
# 15. Add another mutation.

# %% [markdown]
# ## Section 9 — Example Queries

# %%
# Find patients with KRAS mutation

[p for p, muts in patients.items() if "KRAS" in muts]

# %% [markdown]
# ### Exercises
# 16. Find patients with TP53 mutations.
# 17. Count mutations per patient.

# %% [markdown]
# ## Section 10 — Why Graph Libraries Help
# In the next notebook we will use the Python library **networkx** to build and analyze graphs more easily.
